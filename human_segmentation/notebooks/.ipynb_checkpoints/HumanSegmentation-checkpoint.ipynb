# %%
import os
os.chdir('..')

import functools

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

from glob import glob

from lib import *

# %matplotlib inline

# %%
import tensorflow as tf
import tensorflow.contrib as tfcontrib
from tensorflow.python.keras import layers
from tensorflow.python.keras import losses
from tensorflow.python.keras import models
from tensorflow.python.keras import backend as K
# Out:
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_images_filenames(x_path, y_path):
    images_p = os.listdir(x_path)
    images = []
    masks = []
    for image_p in images_p:
        name = image_p.split('.')[0]
        images.append(f'{x_path}/{name}.jpg')
        masks.append(f'{y_path}/{name}.png')
    return images, masks

# %%
x_path = 'data/data/train'
y_path = 'data/data/train_mask'
x_train_filenames, y_train_filenames = get_images_filenames(x_path, y_path)

# %%
x_path = 'data/data/valid'
y_path = 'data/data/valid_mask'
x_valid_filenames, y_valid_filenames = get_images_filenames(x_path, y_path)

# %%
num_train_examples = len(x_train_filenames)
num_val_examples = len(x_valid_filenames)

print("Number of training examples: {}".format(num_train_examples))
print("Number of validation examples: {}".format(num_val_examples))
# Out:
# Number of training examples: 1315
# Number of validation examples: 145

# %%
import matplotlib.image as mpimg

# %%
display_num = 5

r_choices = np.random.choice(num_train_examples, display_num)

plt.figure(figsize=(10, 15))
for i in range(0, display_num * 2, 2):
  img_num = r_choices[i // 2]
  x_pathname = x_train_filenames[img_num]
  y_pathname = y_train_filenames[img_num]
  
  plt.subplot(display_num, 2, i + 1)
  plt.imshow(mpimg.imread(x_pathname))
  plt.title("Original Image")
  
  example_labels = Image.open(y_pathname)
  label_vals = np.unique(example_labels)
  
  plt.subplot(display_num, 2, i + 2)
  plt.imshow(example_labels)
  plt.title("Masked Image")  
  
plt.suptitle("Examples of Images and their Masks")
plt.show()

# %%
img_shape = (320, 256, 3)
batch_size = 10
epochs = 30

# %%
def _process_pathnames(fname, label_path):
  # We map this function onto each pathname pair  
  img_str = tf.read_file(fname)
  img = tf.image.decode_jpeg(img_str, channels=3)

  label_img_str = tf.read_file(label_path)
  label_img = tf.image.decode_png(label_img_str)
  # The label image should only have values of 1 or 0, indicating pixel wise
  # object (car) or not (background). We take the first channel only. 
  #label_img = label_img[:, :, 0]
  #label_img = tf.expand_dims(label_img, axis=-1)
  return img, label_img

# %%
i = 15
img = np.array(Image.open(x_train_filenames[i]))
mask = np.array(Image.open(y_train_filenames[i]))
show_img_with_mask(img, mask)

# %%
def shift_img(output_img, label_img, width_shift_range, height_shift_range):
  """This fn will perform the horizontal or vertical shift"""
  if width_shift_range or height_shift_range:
      if width_shift_range:
        width_shift_range = tf.random_uniform([], 
                                              -width_shift_range * img_shape[1],
                                              width_shift_range * img_shape[1])
      if height_shift_range:
        height_shift_range = tf.random_uniform([],
                                               -height_shift_range * img_shape[0],
                                               height_shift_range * img_shape[0])
      # Translate both 
      output_img = tfcontrib.image.translate(output_img,
                                             [width_shift_range, height_shift_range])
      label_img = tfcontrib.image.translate(label_img,
                                             [width_shift_range, height_shift_range])
  return output_img, label_img

# %%
def flip_img(horizontal_flip, tr_img, label_img):
  if horizontal_flip:
    flip_prob = tf.random_uniform([], 0.0, 1.0)
    tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                lambda: (tr_img, label_img))
  return tr_img, label_img

# %%
def _augment(img,
             label_img,
             resize=None,  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=False,  # Random left right flip,
             width_shift_range=0,  # Randomly translate the image horizontally
             height_shift_range=0):  # Randomly translate the image vertically 
  if resize is not None:
    # Resize both images
    label_img = tf.image.resize_images(label_img, resize)
    img = tf.image.resize_images(img, resize)
  
  if hue_delta:
    img = tf.image.random_hue(img, hue_delta)
  
  img, label_img = flip_img(horizontal_flip, img, label_img)
  img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
  label_img = tf.to_float(label_img) * scale
  img = tf.to_float(img) * scale 
  return img, label_img

# %%
def get_baseline_dataset(filenames, 
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=5, 
                         batch_size=batch_size,
                         shuffle=True):           
  num_x = len(filenames)
  # Create a dataset from the filenames and labels
  dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
  # Map our preprocessing function to every element in our dataset, taking
  # advantage of multithreading
  dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)
  if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
    assert batch_size == 1, "Batching images must be of the same size"

  dataset = dataset.map(preproc_fn, num_parallel_calls=threads)
  
  if shuffle:
    dataset = dataset.shuffle(num_x)
  
  
  # It's necessary to repeat our data for all epochs 
  dataset = dataset.repeat().batch(batch_size)
  return dataset

# %%
tr_cfg = {
    'resize': [img_shape[0], img_shape[1]],
    'scale': 1 / 255.,
    'hue_delta': 0.1,
    'horizontal_flip': True,
    'width_shift_range': 0.1,
    'height_shift_range': 0.1
}
tr_preprocessing_fn = functools.partial(_augment, **tr_cfg)

# %%
val_cfg = {
    'resize': [img_shape[0], img_shape[1]],
    'scale': 1 / 255.,
}
val_preprocessing_fn = functools.partial(_augment, **val_cfg)

# %%
train_ds = get_baseline_dataset(x_train_filenames,
                                y_train_filenames,
                                preproc_fn=tr_preprocessing_fn,
                                batch_size=batch_size)
val_ds = get_baseline_dataset(x_valid_filenames,
                              y_valid_filenames, 
                              preproc_fn=val_preprocessing_fn,
                              batch_size=batch_size)

# %%
temp_ds = get_baseline_dataset(x_train_filenames, 
                               y_train_filenames,
                               preproc_fn=tr_preprocessing_fn,
                               batch_size=1,
                               shuffle=False)
# Let's examine some of these augmented images
data_aug_iter = temp_ds.make_one_shot_iterator()
next_element = data_aug_iter.get_next()
with tf.Session() as sess: 
  batch_of_imgs, label = sess.run(next_element)

  # Running next element in our graph will produce a batch of images
  plt.figure(figsize=(10, 10))
  img = batch_of_imgs[0]

  plt.subplot(1, 2, 1)
  plt.imshow(img)

  plt.subplot(1, 2, 2)
  plt.imshow(label[0, :, :, 0])
  plt.show()

# %%
def conv_block(input_tensor, num_filters):
  encoder = layers.Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
  encoder = layers.BatchNormalization()(encoder)
  encoder = layers.Activation('relu')(encoder)
  encoder = layers.Conv2D(num_filters, (3, 3), padding='same')(encoder)
  encoder = layers.BatchNormalization()(encoder)
  encoder = layers.Activation('relu')(encoder)
  return encoder

def encoder_block(input_tensor, num_filters):
  encoder = conv_block(input_tensor, num_filters)
  encoder_pool = layers.MaxPooling2D((2, 2), strides=(2, 2))(encoder)
  
  return encoder_pool, encoder

def decoder_block(input_tensor, concat_tensor, num_filters):
  decoder = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
  decoder = layers.concatenate([concat_tensor, decoder], axis=-1)
  decoder = layers.BatchNormalization()(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.Conv2D(num_filters, (3, 3), padding='same')(decoder)
  decoder = layers.BatchNormalization()(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.Conv2D(num_filters, (3, 3), padding='same')(decoder)
  decoder = layers.BatchNormalization()(decoder)
  decoder = layers.Activation('relu')(decoder)
  return decoder

# %%
inputs = layers.Input(shape=img_shape)
# 256

encoder0_pool, encoder0 = encoder_block(inputs, 8)
# 128

encoder1_pool, encoder1 = encoder_block(encoder0_pool, 16)
# 64

encoder2_pool, encoder2 = encoder_block(encoder1_pool, 32)
# 32

center = conv_block(encoder2_pool, 64)
# center

decoder2 = decoder_block(center, encoder2, 32)
# 64

decoder1 = decoder_block(decoder2, encoder1, 16)
# 128

decoder0 = decoder_block(decoder1, encoder0, 8)
# 256

outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(decoder0)

# %%
model = models.Model(inputs=[inputs], outputs=[outputs])

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)
    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = losses.binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[dice_loss])

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 320, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 320, 256, 8)  224         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 320, 256, 8)  32          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 320, 256, 8)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 320, 256, 8)  584         activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 320, 256, 8)  32          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 320, 256, 8)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 160, 128, 8)  0           activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 160, 128, 16) 1168        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 160, 128, 16) 64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 160, 128, 16) 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 160, 128, 16) 2320        activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 160, 128, 16) 64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 160, 128, 16) 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 80, 64, 16)   0           activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 80, 64, 32)   4640        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 80, 64, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 80, 64, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 80, 64, 32)   9248        activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 80, 64, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 80, 64, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 40, 32, 32)   0           activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 40, 32, 64)   18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 40, 32, 64)   256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 40, 32, 64)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 40, 32, 64)   36928       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 40, 32, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 40, 32, 64)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 80, 64, 32)   8224        activation_58[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 64, 64)   0           activation_56[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 80, 64, 64)   256         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 80, 64, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 80, 64, 32)   18464       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 80, 64, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 80, 64, 32)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 80, 64, 32)   9248        activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 80, 64, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 80, 64, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 160, 128, 16) 2064        activation_61[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 160, 128, 32) 0           activation_54[0][0]
#                                                                  conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 160, 128, 32) 128         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 160, 128, 32) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 160, 128, 16) 4624        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 160, 128, 16) 64          conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 160, 128, 16) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 160, 128, 16) 2320        activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 160, 128, 16) 64          conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 160, 128, 16) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 320, 256, 8)  520         activation_64[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 320, 256, 16) 0           activation_52[0][0]
#                                                                  conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 320, 256, 16) 64          concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 320, 256, 16) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 320, 256, 8)  1160        activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 320, 256, 8)  32          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 320, 256, 8)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 320, 256, 8)  584         activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 320, 256, 8)  32          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 320, 256, 8)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 320, 256, 1)  9           activation_67[0][0]
# ==================================================================================================
# Total params: 122,681
# Trainable params: 121,753
# Non-trainable params: 928
# __________________________________________________________________________________________________

# %%
save_model_path = 'saved_models/model_2'
cp = tf.keras.callbacks.ModelCheckpoint(filepath=save_model_path, monitor='val_dice_loss', save_best_only=True, verbose=1)

# %%
history = model.fit(train_ds, 
                   steps_per_epoch=int(np.ceil(num_train_examples / float(batch_size))),
                   epochs=epochs,
                   validation_data=val_ds,
                   validation_steps=int(np.ceil(num_val_examples / float(batch_size))),
                   callbacks=[cp])
# Out:
# Epoch 1/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.8255 - dice_loss: 0.2951
# Epoch 00001: val_dice_loss improved from inf to 0.31650, saving model to models/model_2
# 132/132 [==============================] - 52s 392ms/step - loss: 0.8247 - dice_loss: 0.2948 - val_loss: 0.9562 - val_dice_loss: 0.3165
# Epoch 2/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.6658 - dice_loss: 0.2287
# Epoch 00002: val_dice_loss improved from 0.31650 to 0.21640, saving model to models/model_2
# 132/132 [==============================] - 23s 173ms/step - loss: 0.6649 - dice_loss: 0.2285 - val_loss: 0.8403 - val_dice_loss: 0.2164
# Epoch 3/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.6096 - dice_loss: 0.2049
# Epoch 00003: val_dice_loss improved from 0.21640 to 0.19950, saving model to models/model_2
# 132/132 [==============================] - 22s 165ms/step - loss: 0.6091 - dice_loss: 0.2048 - val_loss: 0.9711 - val_dice_loss: 0.1995
# Epoch 4/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.5597 - dice_loss: 0.1867
# Epoch 00004: val_dice_loss improved from 0.19950 to 0.18911, saving model to models/model_2
# 132/132 [==============================] - 22s 168ms/step - loss: 0.5598 - dice_loss: 0.1867 - val_loss: 0.9635 - val_dice_loss: 0.1891
# Epoch 5/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.5173 - dice_loss: 0.1706
# Epoch 00005: val_dice_loss improved from 0.18911 to 0.16512, saving model to models/model_2
# 132/132 [==============================] - 22s 168ms/step - loss: 0.5171 - dice_loss: 0.1706 - val_loss: 0.5142 - val_dice_loss: 0.1651
# Epoch 6/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4903 - dice_loss: 0.1603
# Epoch 00006: val_dice_loss improved from 0.16512 to 0.16286, saving model to models/model_2
# 132/132 [==============================] - 23s 171ms/step - loss: 0.4899 - dice_loss: 0.1602 - val_loss: 0.5691 - val_dice_loss: 0.1629
# Epoch 7/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4732 - dice_loss: 0.1544
# Epoch 00007: val_dice_loss improved from 0.16286 to 0.14551, saving model to models/model_2
# 132/132 [==============================] - 23s 171ms/step - loss: 0.4731 - dice_loss: 0.1543 - val_loss: 0.4947 - val_dice_loss: 0.1455
# Epoch 8/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4570 - dice_loss: 0.1487
# Epoch 00008: val_dice_loss did not improve from 0.14551
# 132/132 [==============================] - 22s 165ms/step - loss: 0.4568 - dice_loss: 0.1486 - val_loss: 0.5482 - val_dice_loss: 0.1467
# Epoch 9/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4400 - dice_loss: 0.1437
# Epoch 00009: val_dice_loss did not improve from 0.14551
# 132/132 [==============================] - 22s 168ms/step - loss: 0.4402 - dice_loss: 0.1436 - val_loss: 0.9148 - val_dice_loss: 0.2060
# Epoch 10/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4377 - dice_loss: 0.1419
# Epoch 00010: val_dice_loss improved from 0.14551 to 0.13495, saving model to models/model_2
# 132/132 [==============================] - 23s 173ms/step - loss: 0.4368 - dice_loss: 0.1417 - val_loss: 0.4541 - val_dice_loss: 0.1349
# Epoch 11/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4190 - dice_loss: 0.1358
# Epoch 00011: val_dice_loss improved from 0.13495 to 0.13011, saving model to models/model_2
# 132/132 [==============================] - 23s 171ms/step - loss: 0.4186 - dice_loss: 0.1357 - val_loss: 0.4497 - val_dice_loss: 0.1301
# Epoch 12/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4172 - dice_loss: 0.1349
# Epoch 00012: val_dice_loss improved from 0.13011 to 0.12535, saving model to models/model_2
# 132/132 [==============================] - 22s 170ms/step - loss: 0.4166 - dice_loss: 0.1348 - val_loss: 0.4489 - val_dice_loss: 0.1253
# Epoch 13/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4028 - dice_loss: 0.1303
# Epoch 00013: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 165ms/step - loss: 0.4034 - dice_loss: 0.1304 - val_loss: 0.4447 - val_dice_loss: 0.1335
# Epoch 14/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.4042 - dice_loss: 0.1307
# Epoch 00014: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 164ms/step - loss: 0.4037 - dice_loss: 0.1306 - val_loss: 0.4662 - val_dice_loss: 0.1472
# Epoch 15/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3935 - dice_loss: 0.1273
# Epoch 00015: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 164ms/step - loss: 0.3944 - dice_loss: 0.1274 - val_loss: 0.4478 - val_dice_loss: 0.1422
# Epoch 16/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3856 - dice_loss: 0.1244
# Epoch 00016: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 167ms/step - loss: 0.3855 - dice_loss: 0.1243 - val_loss: 0.4256 - val_dice_loss: 0.1306
# Epoch 17/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3873 - dice_loss: 0.1251
# Epoch 00017: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 167ms/step - loss: 0.3875 - dice_loss: 0.1252 - val_loss: 0.4119 - val_dice_loss: 0.1280
# Epoch 18/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3746 - dice_loss: 0.1198
# Epoch 00018: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 168ms/step - loss: 0.3739 - dice_loss: 0.1196 - val_loss: 0.4651 - val_dice_loss: 0.1275
# Epoch 19/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3695 - dice_loss: 0.1192
# Epoch 00019: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 168ms/step - loss: 0.3700 - dice_loss: 0.1194 - val_loss: 0.4302 - val_dice_loss: 0.1440
# Epoch 20/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3679 - dice_loss: 0.1185
# Epoch 00020: val_dice_loss did not improve from 0.12535
# 132/132 [==============================] - 22s 168ms/step - loss: 0.3680 - dice_loss: 0.1186 - val_loss: 0.4356 - val_dice_loss: 0.1304
# Epoch 21/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3547 - dice_loss: 0.1144
# Epoch 00021: val_dice_loss improved from 0.12535 to 0.11111, saving model to models/model_2
# 132/132 [==============================] - 23s 172ms/step - loss: 0.3547 - dice_loss: 0.1144 - val_loss: 0.3966 - val_dice_loss: 0.1111
# Epoch 22/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3606 - dice_loss: 0.1155
# Epoch 00022: val_dice_loss did not improve from 0.11111
# 132/132 [==============================] - 22s 168ms/step - loss: 0.3608 - dice_loss: 0.1156 - val_loss: 0.4116 - val_dice_loss: 0.1225
# Epoch 23/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3449 - dice_loss: 0.1111
# Epoch 00023: val_dice_loss did not improve from 0.11111
# 132/132 [==============================] - 22s 167ms/step - loss: 0.3469 - dice_loss: 0.1117 - val_loss: 0.3784 - val_dice_loss: 0.1240
# Epoch 24/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3422 - dice_loss: 0.1096
# Epoch 00024: val_dice_loss did not improve from 0.11111
# 132/132 [==============================] - 22s 167ms/step - loss: 0.3423 - dice_loss: 0.1097 - val_loss: 0.3978 - val_dice_loss: 0.1243
# Epoch 25/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3382 - dice_loss: 0.1088
# Epoch 00025: val_dice_loss did not improve from 0.11111
# 132/132 [==============================] - 22s 167ms/step - loss: 0.3381 - dice_loss: 0.1088 - val_loss: 0.3786 - val_dice_loss: 0.1135
# Epoch 26/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3384 - dice_loss: 0.1085
# Epoch 00026: val_dice_loss did not improve from 0.11111
# 132/132 [==============================] - 22s 166ms/step - loss: 0.3380 - dice_loss: 0.1085 - val_loss: 0.4466 - val_dice_loss: 0.1285
# Epoch 27/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3468 - dice_loss: 0.1109
# Epoch 00027: val_dice_loss did not improve from 0.11111
# 132/132 [==============================] - 22s 167ms/step - loss: 0.3461 - dice_loss: 0.1107 - val_loss: 0.4969 - val_dice_loss: 0.1253
# Epoch 28/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3276 - dice_loss: 0.1051
# Epoch 00028: val_dice_loss improved from 0.11111 to 0.10900, saving model to models/model_2
# 132/132 [==============================] - 22s 170ms/step - loss: 0.3269 - dice_loss: 0.1049 - val_loss: 0.3558 - val_dice_loss: 0.1090
# Epoch 29/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3324 - dice_loss: 0.1064
# Epoch 00029: val_dice_loss did not improve from 0.10900
# 132/132 [==============================] - 22s 168ms/step - loss: 0.3328 - dice_loss: 0.1066 - val_loss: 0.3796 - val_dice_loss: 0.1198
# Epoch 30/30
# 131/132 [============================>.] - ETA: 0s - loss: 0.3282 - dice_loss: 0.1044
# Epoch 00030: val_dice_loss did not improve from 0.10900
# 132/132 [==============================] - 22s 169ms/step - loss: 0.3281 - dice_loss: 0.1044 - val_loss: 0.5421 - val_dice_loss: 0.1370

# %%
dice = history.history['dice_loss']
val_dice = history.history['val_dice_loss']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, dice, label='Training Dice Loss')
plt.plot(epochs_range, val_dice, label='Validation Dice Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Dice Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
model = models.load_model(save_model_path, custom_objects={'bce_dice_loss': bce_dice_loss,
                                                           'dice_loss': dice_loss})

# %%
data_aug_iter = val_ds.make_one_shot_iterator()
next_element = data_aug_iter.get_next()

# Running next element in our graph will produce a batch of images
plt.figure(figsize=(10, 20))
for i in range(5):
  batch_of_imgs, label = tf.keras.backend.get_session().run(next_element)
  img = batch_of_imgs[0]
  predicted_label = model.predict(batch_of_imgs)[0]

  plt.subplot(5, 3, 3 * i + 1)
  plt.imshow(img)
  plt.title("Input image")
  
  plt.subplot(5, 3, 3 * i + 2)
  plt.imshow(label[0, :, :, 0])
  plt.title("Actual Mask")
  plt.subplot(5, 3, 3 * i + 3)
  plt.imshow(predicted_label[:, :, 0])
  plt.title("Predicted Mask")
plt.suptitle("Examples of Input Image, Label, and Prediction")
plt.show()
