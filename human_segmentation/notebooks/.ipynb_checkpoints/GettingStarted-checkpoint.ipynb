# %%
import os
os.chdir("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

from glob import glob

from lib import *

# %matplotlib inline
# Out:
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\programs\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Задача

# %% [markdown]
# **Требуется:** предложить модель, сегментирующую человека на фотографии.
#
# **Вход:** фотография 320x240x3.
# **Выход:** маска человека 320x240.
# **Метрика:** [Dice coefficient](https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient).
#
#
# Данные представляют из себя набор фотографий человека и маски, определяющей положение человека на фотографии.
# Доступные данные разделены на несколько папок:
# - `train` содержит фотографии 320x240x3;
# - `train_mask` содержит маски для фотографий из `train` 320x240;
# - `valid` содержит фотографии 320x240x3;
# - `valid_mask` содержит маски для фотографий из `valid` 320x240;
# - `test` содержит фотографии 320x240x3.
#
# Для лучшей модели требуется создать 2 файла, которые необходимы для валидации Вашего решения:
# - сохраненные маски для картинок из `valid` в формате `pred_valid_template.csv`;
# - html страницу с предсказанием модели для всех картинок из `test` и папку с используемыми картинками в этой html странице.
#
# Также необходимо:
# - подготовить код для проверки (докстринги, PEP8);
# - создать отчет (можно прямо в ноутбуке) с описанием Вашего исследования, гипотез и т.п.
#
# Примеры приведены ниже.

# %% [markdown]
# ---

# %% [markdown]
# # Данные, метрики и доступные функции

# %% [markdown]
# Посмотрим на данные:

# %%
path = "data/data/train"
images = os.listdir(path)
ind = np.random.choice(images).split(".")[0]

img = np.array(Image.open(f"{path}/{ind}.jpg"))
mask = np.array(Image.open(f"{path}_mask/{ind}.png"))
show_img_with_mask(img, mask)

# %%
mask.shape
# Out:
# (320, 240)

# %%
img.shape
# Out:
# (320, 240, 3)

# %% [markdown]
# Пример подсчета метрики:

# %%
random_mask = np.random.randint(low=0, high=2, size=mask.shape)
get_dice(mask, random_mask)
# Out:
# 0.5220403179586847

# %% [markdown]
# Можно для последовательности масок вычислить среднее значение метрики:

# %%
random_masks_1 = [np.random.randint(low=0, high=2, size=mask.shape) for i in range(10)]
random_masks_2 = [np.random.randint(low=0, high=2, size=mask.shape) for i in range(10)]
get_dice(random_masks_1, random_masks_2)
# Out:
# 0.5004044962508746

# %% [markdown]
# Пример использования функций `encode_rle` и `decode_rle`:
# 1. Функция `encode_rle` используется для кодирования маски в строку для последующей записи в файл;
# 2. Функция `decode_rle` используется для восстановления маски по закодированной строке.

# %%
rle_mask = encode_rle(mask)
rle_mask
# Out:
# '5590 1 5828 5 6067 3 7505 2 7513 2 7744 14 7759 1 7762 3 7773 2 7971 3 7977 2 7983 21 8007 9 8018 5 8207 1 8209 55 8442 65 8674 3 8678 71 8911 79 9146 86 9381 92 9620 94 9857 98 10095 101 10333 104 10571 108 10810 111 11048 115 11286 118 11525 120 11764 122 12003 123 12241 125 12481 125 12721 125 12961 125 13201 125 13441 124 13681 124 13921 124 14161 124 14401 124 14641 124 14881 124 15121 124 15361 124 15601 123 15841 124 16081 124 16321 125 16561 126 16801 126 17041 126 17281 127 17521 127 17761 128 18001 127 18129 1 18241 129 18481 128 18610 1 18721 130 18961 129 19201 129 19331 1 19441 131 19681 130 19812 1 19921 128 20050 3 20161 128 20290 4 20401 129 20531 1 20533 1 20641 129 20771 3 20881 129 21011 2 21014 1 21121 130 21252 1 21254 1 21361 130 21492 4 21601 136 21841 131 21973 4 22081 136 22321 137 22561 137 22801 137 23041 138 23281 138 23521 138 23761 
9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 1  1316  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 2  1317  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 3  1318  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 4  1319  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...

# %% [markdown]
# Для данных из `test` требуется создать html страницу + картинки для нее.
# Это можно сделать с помощью функции `get_html`, как показано ниже.

# %%
paths_to_imgs = sorted([i.replace('\\', '/') for i in glob("data/data/valid/*")])
pred_masks = [np.array(Image.open(path)) for path in sorted([i.replace('\\', '/') for i in glob("data/data/valid_mask/*")])]

_ = get_html(paths_to_imgs, pred_masks, path_to_save="results/example")

# %% [markdown]
# В папке `results` создался файл `example.html` и папка `examples` с используемыми картинками.

# %%
paths_to_imgs
# Out:
# ['data/data/valid/1315.jpg',
#  'data/data/valid/1316.jpg',
#  'data/data/valid/1317.jpg',
#  'data/data/valid/1318.jpg',
#  'data/data/valid/1319.jpg',
#  'data/data/valid/1320.jpg',
#  'data/data/valid/1321.jpg',
#  'data/data/valid/1322.jpg',
#  'data/data/valid/1323.jpg',
#  'data/data/valid/1324.jpg',
#  'data/data/valid/1325.jpg',
#  'data/data/valid/1326.jpg',
#  'data/data/valid/1327.jpg',
#  'data/data/valid/1328.jpg',
#  'data/data/valid/1329.jpg',
#  'data/data/valid/1330.jpg',
#  'data/data/valid/1331.jpg',
#  'data/data/valid/1332.jpg',
#  'data/data/valid/1333.jpg',
#  'data/data/valid/1334.jpg',
#  'data/data/valid/1335.jpg',
#  'data/data/valid/1336.jpg',
#  'data/data/valid/1337.jpg',
#  'data/data/valid/1338.jpg',
#  'data/data/valid/1339.jpg',
#  'data/data/valid/1340.jpg',
#  'data/data/valid/1341.jpg',
#  'data/data/valid/1342.jpg',
#  'data/data/valid/1343.jpg',
#  'data/data/valid/1344.jpg',
#  'data/data/valid/1345.jpg',
#  'data/data/valid/1346.jpg',
#  'data/data/valid/1347.jpg',
#  'data/data/valid/1348.jpg',
#  'data/data/valid/1349.jpg',
#  'data/data/valid/1350.jpg',
#  'data/data/valid/1351.jpg',
#  'data/data/valid/1352.jpg',
#  'data/data/valid/1353.jpg',
#  'data/data/valid/1354.jpg',
#  'data/data/valid/1355.jpg',
#  'data/data/valid/1356.jpg',
#  'data/data/valid/1357.jpg',
#  'data/data/valid/1358.jpg',
#  'data/data/valid/1359.jpg',
#  'data/data/valid/1360.jpg',
#  'data/data/valid/1361.jpg',
#  'data/data/valid/1362.jpg',
#  'data/data/valid/1363.jpg',
#  'data/data/valid/1364.jpg',
#  'data/data/valid/1365.jpg',
#  'data/data/valid/1366.jpg',
#  'data/data/valid/1367.jpg',
#  'data/data/valid/1368.jpg',
#  'data/data/valid/1369.jpg',
#  'data/data/valid/1370.jpg',
#  'data/data/valid/1371.jpg',
#  'data/data/valid/1372.jpg',
#  'data/data/valid/1373.jpg',
#  'data/data/valid/1374.jpg',
#  'data/data/valid/1375.jpg',
#  'data/data/valid/1376.jpg',
#  'data/data/valid/1377.jpg',
#  'data/data/valid/1378.jpg',
#  'data/data/valid/1379.jpg',
#  'data/data/valid/1380.jpg',
#  'data/data/valid/1381.jpg',
#  'data/data/valid/1382.jpg',
#  'data/data/valid/1383.jpg',
#  'data/data/valid/1384.jpg',
#  'data/data/valid/1385.jpg',
#  'data/data/valid/1386.jpg',
#  'data/data/valid/1387.jpg',
#  'data/data/valid/1388.jpg',
#  'data/data/valid/1389.jpg',
#  'data/data/valid/1390.jpg',
#  'data/data/valid/1391.jpg',
#  'data/data/valid/1392.jpg',
#  'data/data/valid/1393.jpg',
#  'data/data/valid/1394.jpg',
#  'data/data/valid/1395.jpg',
#  'data/data/valid/1396.jpg',
#  'data/data/valid/1397.jpg',
#  'data/data/valid/1398.jpg',
#  'data/data/valid/1399.jpg',
#  'data/data/valid/1400.jpg',
#  'data/data/valid/1401.jpg',
#  'data/data/valid/1402.jpg',
#  'data/data/valid/1403.jpg',
#  'data/data/valid/1404.jpg',
#  'data/data/valid/1405.jpg',
#  'data/data/valid/1406.jpg',
#  'data/data/valid/1407.jpg',
#  'data/data/valid/1408.jpg',
#  'data/data/valid/1409.jpg',
#  'data/data/valid/1410.jpg',
#  'data/data/valid/1411.jpg',
#  'data/data/valid/1412.jpg',
#  'data/data/valid/1413.jpg',
#  'data/data/valid/1414.jpg',
#  'data/data/valid/1415.jpg',
#  'data/data/valid/1416.jpg',
#  'data/data/valid/1417.jpg',
#  'data/data/valid/1418.jpg',
#  'data/data/valid/1419.jpg',
#  'data/data/valid/1420.jpg',
#  'data/data/valid/1421.jpg',
#  'data/data/valid/1422.jpg',
#  'data/data/valid/1423.jpg',
#  'data/data/valid/1424.jpg',
#  'data/data/valid/1425.jpg',
#  'data/data/valid/1426.jpg',
#  'data/data/valid/1427.jpg',
#  'data/data/valid/1428.jpg',
#  'data/data/valid/1429.jpg',
#  'data/data/valid/1430.jpg',
#  'data/data/valid/1431.jpg',
#  'data/data/valid/1432.jpg',
#  'data/data/valid/1433.jpg',
#  'data/data/valid/1434.jpg',
#  'data/data/valid/1435.jpg',
#  'data/data/valid/1436.jpg',
#  'data/data/valid/1437.jpg',
#  'data/data/valid/1438.jpg',
#  'data/data/valid/1439.jpg',
#  'data/data/valid/1440.jpg',
#  'data/data/valid/1441.jpg',
#  'data/data/valid/1442.jpg',
#  'data/data/valid/1443.jpg',
#  'data/data/valid/1444.jpg',
#  'data/data/valid/1445.jpg',
#  'data/data/valid/1446.jpg',
#  'data/data/valid/1447.jpg',
#  'data/data/valid/1448.jpg',
#  'data/data/valid/1449.jpg',
#  'data/data/valid/1450.jpg',
#  'data/data/valid/1451.jpg',
#  'data/data/valid/1452.jpg',
#  'data/data/valid/1453.jpg',
#  'data/data/valid/1454.jpg',
#  'data/data/valid/1455.jpg',
#  'data/data/valid/1456.jpg',
#  'data/data/valid/1457.jpg',
#  'data/data/valid/1458.jpg',
#  'data/data/valid/1459.jpg']

# %%
glob
# Out:
# <function glob.glob(pathname, *, recursive=False)>

# %%
glob = win_glob_hack_decorator(glob)
